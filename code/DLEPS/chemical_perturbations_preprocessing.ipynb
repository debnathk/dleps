# %%
# import pandas as pd

# %%
# df = pd.read_csv('../../data/l1000_cp.txt', delimiter="\t", header=None)
# df.head(10)
# Out:
#                                       0    1       2        3         4    \
# 0     ABY001_A375_XH_A13_afatinib_10uM up  NaN   RRAGC     VPS8     KCNJ2
# 1   ABY001_A375_XH_A13_afatinib_10uM down  NaN    PCNA   S100A7     DNMT1
# 2    ABY001_A375_XH_A14_erlotinib_10uM up  NaN  CDKN2C    TIMP3  COLGALT2
# 3  ABY001_A375_XH_A14_erlotinib_10uM down  NaN    PCP4   SPINK1    STEAP1
# 4    ABY001_A375_XH_A15_neratinib_10uM up  NaN   ITGAE    PRPF4     UBE2S
# 5  ABY001_A375_XH_A15_neratinib_10uM down  NaN  RPS4Y1    KRT18     THBS1
# 6    ABY001_A375_XH_A16_lapatinib_10uM up  NaN  SLC1A3     TPPP   SELENOP
# 7  ABY001_A375_XH_A16_lapatinib_10uM down  NaN   PUF60   HSPA1A    SPINK1
# 8    ABY001_A375_XH_B13_afatinib_2.5uM up  NaN     RP2  S100A11    CHST11
# 9  ABY001_A375_XH_B13_afatinib_2.5uM down  NaN    MT1E   MAMLD1     SFRP1
#
#         5         6         7         8        9    ...        242      243  \
# 0     DUSP5      BEX1     LIMS1     RAB13  COLEC12  ...        GEM     BEX3
# ...

# %%
# Remove nan column
# df_copy = df.copy()
# df_filtered = df_copy.drop(columns=[1], axis=1)
# print(df_filtered.shape)
# print(df.shape)
# Out:
# (1436110, 251)
# (1436110, 252)

# %%
# df_filtered.to_csv("../../data/l100_chemical_perturbagens.csv", index=None)

# %%
import pandas as pd
df = pd.read_csv('../../data/l100_chemical_perturbagens.csv')
df.head(10)
# Out:
#                                         0       2        3         4  \
# 0     ABY001_A375_XH_A13_afatinib_10uM up   RRAGC     VPS8     KCNJ2
# 1   ABY001_A375_XH_A13_afatinib_10uM down    PCNA   S100A7     DNMT1
# 2    ABY001_A375_XH_A14_erlotinib_10uM up  CDKN2C    TIMP3  COLGALT2
# 3  ABY001_A375_XH_A14_erlotinib_10uM down    PCP4   SPINK1    STEAP1
# 4    ABY001_A375_XH_A15_neratinib_10uM up   ITGAE    PRPF4     UBE2S
# 5  ABY001_A375_XH_A15_neratinib_10uM down  RPS4Y1    KRT18     THBS1
# 6    ABY001_A375_XH_A16_lapatinib_10uM up  SLC1A3     TPPP   SELENOP
# 7  ABY001_A375_XH_A16_lapatinib_10uM down   PUF60   HSPA1A    SPINK1
# 8    ABY001_A375_XH_B13_afatinib_2.5uM up     RP2  S100A11    CHST11
# 9  ABY001_A375_XH_B13_afatinib_2.5uM down    MT1E   MAMLD1     SFRP1
#
#           5         6         7         8        9          10  ...  \
# 0     DUSP5      BEX1     LIMS1     RAB13  COLEC12      ARMCX2  ...
# 1     S100P    S100A9     PUF60   TMEM45A   GOLT1B      PRSS23  ...
# ...
